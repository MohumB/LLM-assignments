# %% [markdown]
# ## CA 4 - Part 2, LLMs Spring 2025
#
# - **Name:**
# - **Student ID:**
#
# ---
# #### Your submission should be named using the following format: `CA4_LASTNAME_STUDENTID.ipynb`.
#
# ---
#
# TA Email: miladmohammadi@ut.ac.ir
#
# ##### *How to do this problem set:*
#
# - Some questions require writing Python code and computing results, and the rest of them have written answers. For coding problems, you will have to fill out all code blocks that say `YOUR CODE HERE`.
#
# - For text-based answers, you should replace the text that says ```Your Answer Here``` with your actual answer.
#
# - There is no penalty for using AI assistance on this homework as long as you fully disclose it in the final cell of this notebook (this includes storing any prompts that you feed to large language models). That said, anyone caught using AI assistance without proper disclosure will receive a zero on the assignment (we have several automatic tools to detect such cases). We're literally allowing you to use it with no limitations, so there is no reason to lie!
#
# ---
#
# ##### *Academic honesty*
#
# - We will audit the Colab notebooks from a set number of students, chosen at random. The audits will check that the code you wrote actually generates the answers in your notebook. If you turn in correct answers on your notebook without code that actually generates those answers, we will consider this a serious case of cheating.
#
# - We will also run automatic checks of Colab notebooks for plagiarism. Copying code from others is also considered a serious case of cheating.
#
# ---

# %% [markdown]
# ## Text2SQL

# %% [markdown]
# In this section, you will progressively build and evaluate multiple Text-to-SQL pipelines. You’ll start with a simple prompting-based baseline, then design a graph-based routing system using chain-of-thought and schema reasoning, and finally construct a ReAct agent that interacts with the schema via tools. Each stage demonstrates a different strategy for generating SQL from natural language using LLMs.

# %% [markdown]
# ### Initializations

# %% [markdown]
# This section prepares the environment and initializes the LLM model (Gemini) to be used in later parts of the notebook.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: langchain in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.3.25)
# Requirement already satisfied: langgraph in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.4.7)
# Requirement already satisfied: langchain-core in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.3.61)
# Requirement already satisfied: langchain-google-genai in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.1.4)
# Requirement already satisfied: tqdm in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: func-timeout in /usr/local/python/3.12.1/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (4.3.5)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 2)) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 2)) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 2)) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/codespace/.local/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-core->-r requirements.txt (line 4)) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-core->-r requirements.txt (line 4)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core->-r requirements.txt (line 4)) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (0.23.0)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langgraph->-r requirements.txt (line 3)) (2.0.26)
# Requirement already satisfied: langgraph-prebuilt>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langgraph->-r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langgraph->-r requirements.txt (line 3)) (0.1.70)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langgraph->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-google-genai->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-google-genai->-r requirements.txt (line 5)) (0.6.18)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (2.40.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (6.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (1.72.0rc1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (1.72.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 7)) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 7)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 7)) (2025.1)
# Requirement already satisfied: ormsgpack<2.0.0,>=1.8.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langgraph-checkpoint>=2.0.26->langgraph->-r requirements.txt (line 3)) (1.10.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Load API Key (2 Points)

# %% [markdown]
# **Task:** Load the Gemini API key stored in the `.env` file and set it as an environment variable so it can be used to authenticate API requests later.
#
# * Use `dotenv` to load the file.
# * Extract the API key with `os.getenv`.

# %%
# import os
# from dotenv import load_dotenv

# # Load environment variables from .env file
# load_dotenv()

# # Extract the API key
# GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# if not GOOGLE_API_KEY:
#     raise ValueError("GOOGLE_API_KEY not found in environment variables")

# # Set the API key as an environment variable for use by langchain-google-genai
# os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %% [markdown]
# #### Create ChatModel (3 Points)

# %% [markdown]
# **Task:** Create an instance of the Gemini LLM using LangChain. You should configure the model with proper parameters for our task.
#
# Note: You may use any model that supports Structured Output and Tool Use. We recommend using gemini-2.5-flash-preview-05-20 from Google AI Studio, as it offers a generous free tier.

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI

# # Create an instance of the Gemini LLM
# llm = ChatGoogleGenerativeAI(
#     model="gemini-2.0-flash-exp",  # Using the recommended model
#     temperature=0,  # Set to 0 for more deterministic SQL generation
#     max_tokens=2048,  # Sufficient for SQL queries
#     top_p=1.0,
#     top_k=40
# )

# %%
from dotenv import load_dotenv
import os
from langchain.chat_models import init_chat_model

load_dotenv()
llm = init_chat_model("anthropic:claude-3-7-sonnet-latest")

# %% [markdown]
# ### Baseline

# %% [markdown]
# In this section, you'll build a simple baseline pipeline that directly converts a question and schema into a SQL query using a single prompt.

# %% [markdown]
# #### Baseline Function (5 Points)

# %% [markdown]
# **Task:** Implement a function that sends a system message defining the task, and a user message containing the input question and schema. The LLM should return the SQL query formatted as: "```sql\n[query]```"

# %%
def run_baseline(question: str, schema: str):
    # Create system message defining the task
    system_message = """You are an expert SQL query generator. Given a natural language question and database schema, generate a syntactically correct SQL query that answers the question.

Instructions:
- Analyze the question and schema carefully
- Generate only the SQL query without any explanation
- Format your response as: ```sql\n[query]```
- Ensure the query is syntactically correct and uses only tables/columns from the provided schema
- Use proper SQL syntax and conventions"""

    # Create user message with question and schema
    user_message = f"""Question: {question}

Database Schema:
{schema}

Generate the SQL query to answer this question."""

    # Get response from LLM
    response = llm.invoke([
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message}
    ])
    
    sql_query = response.content
    return sql_query

# %% [markdown]
# #### Run and Evaluate (Estimated Run Time 5-10min)

# %% [markdown]
# Run your baseline function over the dataset provided.

# %%
from method_run import run_method
import re

def function_template(item):
    result = run_baseline(item['question'], item['schema'])
    # First try to extract query from markdown SQL block
    match = re.search(r'```sql\n(.*?)```', result, re.DOTALL)
    if match:
        query = match.group(1).strip()
    else:
        # If no markdown block found, try to extract just SQL query
        query = result.strip()
        # Remove any ```sql or ``` if present without proper formatting
        query = re.sub(r'```sql|```', '', query).strip()
    
    print(f"Question: {item['question']}")
    print(f"Schema: {item['schema']}")
    print(f"Generated SQL: {query}\n")
    
    return {**item, 'sql': query}

run_method(function_template, SLEEP_TIME=10)

#Run on mode=nano if you want to test it on a smaller dataset
#run_method(function_template, SLEEP_TIME=10, mode="nano")
# Out:
# File not found: data/dev_databases/student_club/database_description/event.csv
# File not found: data/dev_databases/student_club/database_description/major.csv
# File not found: data/dev_databases/student_club/database_description/zip_code.csv
# File not found: data/dev_databases/student_club/database_description/attendance.csv
# File not found: data/dev_databases/student_club/database_description/budget.csv
# File not found: data/dev_databases/student_club/database_description/expense.csv
# File not found: data/dev_databases/student_club/database_description/income.csv
# File not found: data/dev_databases/student_club/database_description/member.csv
#   0%|          | 0/18 [00:00<?, ?it/s]
# Question: Find the percentage of atoms with single bond. (Evidence: single bond refers to bond_type = '-'; percentage = DIVIDE(SUM(bond_type = '-'), COUNT(bond_id)) as percentage)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Generated SQL: SELECT (SUM(CASE WHEN bond_type = '-' THEN 1 ELSE 0 END) * 100.0 / COUNT(bond_id)) AS percentage
# FROM bond
#   6%|▌         | 1/18 [00:12<03:25, 12.08s/it]
# Question: Indicate which atoms are connected in non-carcinogenic type molecules. (Evidence: label = '-' means molecules are non-carcinogenic)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Generated SQL: SELECT DISTINCT a1.atom_id, a2.atom_id2
# FROM atom a1
# JOIN connected c ON a1.atom_id = c.atom_id
# JOIN atom a2 ON c.atom_id2 = a2.atom_id
# JOIN molecule m ON a1.molecule_id = m.molecule_id
# WHERE m.label = '-'
#  11%|█         | 2/18 [00:25<03:24, 12.79s/it]
# Question: What is the average number of bonds the atoms with the element iodine have? (Evidence: atoms with the element iodine refers to element = 'i'; average = DIVIDE(COUND(bond_id), COUNT(atom_id)) where element = 'i')
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Generated SQL: SELECT AVG(atom_bonds.bond_count) AS avg_bonds_for_iodine
# FROM (
#     SELECT a.atom_id, COUNT(c.bond_id) AS bond_count
#     FROM atom a
#     LEFT JOIN connected c ON a.atom_id = c.atom_id
#     WHERE a.element = 'i'
#     GROUP BY a.atom_id
# ) AS atom_bonds
#  17%|█▋        | 3/18 [00:38<03:12, 12.86s/it]
# Question: List down two molecule id of triple bond non carcinogenic molecules with element carbon. (Evidence: carbon refers to element = 'c'; triple bond refers to bond_type = '#'; label = '-' means molecules are non-carcinogenic)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Generated SQL: SELECT DISTINCT a.molecule_id
# FROM atom a
# JOIN bond b ON a.molecule_id = b.molecule_id
# JOIN molecule m ON a.molecule_id = m.molecule_id
# WHERE a.element = 'c'
# AND b.bond_type = '#'
# AND m.label = '-'
# LIMIT 2
#  22%|██▏       | 4/18 [00:51<02:59, 12.85s/it]
# Question: What are the elements of the toxicology and label of molecule TR060? (Evidence: TR060 is the molecule id; label = '+' mean molecules are carcinogenic; label = '-' means molecules are non-carcinogenic; element = 'cl' means Chlorine; element = 'c' means Carbon; element = 'h' means Hydrogen; element = 'o' means Oxygen, element = 's' means Sulfur; element = 'n' means Nitrogen, element = 'p' means Phosphorus, element = 'na' means Sodium, element = 'br' means Bromine, element = 'f' means Fluorine; element = 'i' means Iodine; element = 'sn' means Tin; element = 'pb' means Lead; element = 'te' means Tellurium; element = 'ca' means Calcium)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Generated SQL: SELECT a.element, m.label
# FROM atom a
# JOIN molecule m ON a.molecule_id = m.molecule_id
# WHERE a.molecule_id = 'TR060'
#  28%|██▊       | 5/18 [01:03<02:45, 12.74s/it]
# Question: What are the elements for bond id TR001_10_11? (Evidence: element = 'cl' means Chlorine; element = 'c' means Carbon; element = 'h' means Hydrogen; element = 'o' means Oxygen, element = 's' means Sulfur; element = 'n' means Nitrogen, element = 'p' means Phosphorus, element = 'na' means Sodium, element = 'br' means Bromine, element = 'f' means Fluorine; element = 'i' means Iodine; element = 'sn' means Tin; element = 'pb' means Lead; element = 'te' means Tellurium; element = 'ca' means Calcium)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Generated SQL: SELECT DISTINCT a.element
# FROM atom a
# JOIN connected c ON a.atom_id = c.atom_id OR a.atom_id = c.atom_id2
# WHERE c.bond_id = 'TR001_10_11'
#  33%|███▎      | 6/18 [01:15<02:30, 12.53s/it]
# Question: How many superheroes were published by Dark Horse Comics? (Evidence: published by Dark Horse Comics refers to publisher_name = 'Dark Horse Comics';)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Generated SQL: SELECT COUNT(*)
# FROM superhero s
# JOIN publisher p ON s.publisher_id = p.id
# WHERE p.publisher_name = 'Dark Horse Comics'
#  39%|███▉      | 7/18 [01:27<02:16, 12.39s/it]
# Question: What are the race and alignment of Cameron Hicks? (Evidence: Cameron Hicks refers to superhero_name = 'Cameron Hicks';)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Generated SQL: SELECT r.race, a.alignment
# FROM superhero s
# JOIN race r ON s.race_id = r.id
# JOIN alignment a ON s.alignment_id = a.id
# WHERE s.superhero_name = 'Cameron Hicks'
#  44%|████▍     | 8/18 [01:39<02:01, 12.13s/it]
# Question: Among the superheroes with height from 170 to 190, list the names of the superheroes with no eye color. (Evidence: height from 170 to 190 refers to height_cm BETWEEN 170 AND 190; no eye color refers to eye_colour_id = 1)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Generated SQL: SELECT s.superhero_name
# FROM superhero s
# WHERE s.height_cm BETWEEN 170 AND 190
# AND s.eye_colour_id = 1
#  50%|█████     | 9/18 [01:51<01:48, 12.06s/it]
# Question: List down at least five superpowers of male superheroes. (Evidence: male refers to gender = 'Male'; superpowers refers to power_name;)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Generated SQL: SELECT DISTINCT sp.power_name
# FROM superpower sp
# JOIN hero_power hp ON sp.id = hp.power_id
# JOIN superhero sh ON hp.hero_id = sh.id
# JOIN gender g ON sh.gender_id = g.id
# WHERE g.gender = 'Male'
# LIMIT 5
#  56%|█████▌    | 10/18 [02:03<01:36, 12.05s/it]
# Question: What is the percentage of superheroes who act in their own self-interest or make decisions based on their own moral code? Indicate how many of the said superheroes were published by Marvel Comics. (Evidence: published by Marvel Comics refers to publisher_name = 'Marvel Comics'; superheroes who act in their own self-interest or make decisions based on their own moral code refers to alignment = 'Bad'; calculation = MULTIPLY(DIVIDE(SUM(alignment = 'Bad); count(id)), 100))
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Generated SQL: WITH BadHeroes AS (
#     SELECT s.id, s.publisher_id
#     FROM superhero s
#     JOIN alignment a ON s.alignment_id = a.id
#     WHERE a.alignment = 'Bad'
# )
#
# SELECT
#     (COUNT(DISTINCT b.id) * 100.0 / COUNT(DISTINCT s.id)) AS percentage_of_bad_heroes,
#     SUM(CASE WHEN p.publisher_name = 'Marvel Comics' THEN 1 ELSE 0 END) AS marvel_bad_heroes
# FROM superhero s
# LEFT JOIN BadHeroes b ON s.id = b.id
# LEFT JOIN publisher p ON b.publisher_id = p.id;
#  61%|██████    | 11/18 [02:16<01:27, 12.47s/it]
# Question: Which publisher created more superheroes: DC or Marvel Comics? Find the difference in the number of superheroes. (Evidence: DC refers to publisher_name = 'DC Comics'; Marvel Comics refers to publisher_name = 'Marvel Comics'; if SUM(publisher_name = 'DC Comics') > SUM(publisher_name = 'Marvel Comics'), it means DC Comics published more superheroes than Marvel Comics; if SUM(publisher_name = 'Marvel Comics') > SUM(publisher_name = 'Marvel Comics'), it means Marvel Comics published more heroes than DC Comics; difference = SUBTRACT(SUM(publisher_name = 'DC Comics'), SUM(publisher_name = 'Marvel Comics'));)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Generated SQL: WITH dc_count AS (
#     SELECT COUNT(*) AS count
#     FROM superhero
#     JOIN publisher ON superhero.publisher_id = publisher.id
#     WHERE publisher.publisher_name = 'DC Comics'
# ),
# marvel_count AS (
#     SELECT COUNT(*) AS count
#     FROM superhero
#     JOIN publisher ON superhero.publisher_id = publisher.id
#     WHERE publisher.publisher_name = 'Marvel Comics'
# )
# SELECT
#     CASE
#         WHEN dc_count.count > marvel_count.count THEN 'DC Comics'
#         ELSE 'Marvel Comics'
#     END AS publisher_with_more_heroes,
#     ABS(dc_count.count - marvel_count.count) AS difference
# FROM dc_count, marvel_count;
#  67%|██████▋   | 12/18 [02:30<01:16, 12.79s/it]
# Question: Who was the first one paid his/her dues? Tell the full name. (Evidence: full name refers to first_name, last_name; first paid dues refers to MIN(received_date) where source = 'Dues')
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Generated SQL: SELECT m.first_name, m.last_name
# FROM member m
# JOIN income i ON m.member_id = i.link_to_member
# WHERE i.source = 'Dues'
# ORDER BY i.date_received ASC
# LIMIT 1
#  72%|███████▏  | 13/18 [02:42<01:02, 12.45s/it]
# Question: How many income are received with an amount of 50? (Evidence: amount of 50 refers to amount = 50)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Generated SQL: SELECT COUNT(*) FROM income WHERE amount = 50
#  78%|███████▊  | 14/18 [02:53<00:48, 12.24s/it]
# Question: Name the event with the highest amount spent on advertisement. (Evidence: event refers to event_name; highest amount spent on advertisement refers to MAX(spent) where category = 'Advertisement')
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Generated SQL: SELECT e.event_name
# FROM event e
# JOIN budget b ON e.event_id = b.link_to_event
# WHERE b.category = 'Advertisement'
# ORDER BY b.spent DESC
# LIMIT 1;
#  83%|████████▎ | 15/18 [03:06<00:36, 12.24s/it]
# Question: Based on the total cost for all event, what is the percentage of cost for Yearly Kickoff event? (Evidence: DIVIDE(SUM(cost where event_name = 'Yearly Kickoff'), SUM(cost)) * 100)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Generated SQL: SELECT
#   (SUM(CASE WHEN e.event_name = 'Yearly Kickoff' THEN ex.cost ELSE 0 END) / SUM(ex.cost)) * 100 AS yearly_kickoff_percentage
# FROM
#   expense ex
# JOIN
#   budget b ON ex.link_to_budget = b.budget_id
# JOIN
#   event e ON b.link_to_event = e.event_id
#  89%|████████▉ | 16/18 [03:18<00:24, 12.35s/it]
# Question: Calculate the total average cost that Elijah Allen spent in the events on September and October. (Evidence: events in September and October refers to month(expense_date) = 9 AND MONTH(expense_date) = 10)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Generated SQL: SELECT AVG(e.cost) as average_cost
# FROM expense e
# JOIN member m ON e.link_to_member = m.member_id
# WHERE m.first_name = 'Elijah'
# AND m.last_name = 'Allen'
# AND (MONTH(e.expense_date) = 9 OR MONTH(e.expense_date) = 10)
#  94%|█████████▍| 17/18 [03:32<00:12, 12.91s/it]
# Question: Find the name and date of events with expenses for pizza that were more than fifty dollars but less than a hundred dollars. (Evidence: name of event refers to event_name; date of event refers to event_date; expenses for pizza refers to expense_description = 'Pizza' where cost > 50 and cost < 100)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Generated SQL: SELECT e.event_name, e.event_date
# FROM event e
# JOIN budget b ON e.event_id = b.link_to_event
# JOIN expense ex ON b.budget_id = ex.link_to_budget
# WHERE ex.expense_description = 'Pizza'
# AND ex.cost > 50
# AND ex.cost < 100
# 100%|██████████| 18/18 [03:46<00:00, 12.58s/it]
# Starting to compare without knowledge for ex
# Process finished successfully
# start calculate
#                      simple               moderate             challenging          total
# count                6                    6                    6                    18
# ======================================    ACCURACY    =====================================
# accuracy             66.67                100.00               83.33                83.33
# ===========================================================================================
# Finished evaluation

# %% [markdown]
# ### Chain/Router

# %% [markdown]
# Here, you will build a more advanced system that routes the query through different paths based on question difficulty. Easier questions go straight to query generation; harder ones go through schema path extraction first.

# %% [markdown]
# #### Define State (5 Points)

# %% [markdown]
# **Task:** Define a `RouterGraphState` using `MessagesState` and `pydantic` that contains:
# * The input question and schema
# * The predicted difficulty level
# * The extracted schema path
# * The final query

# %%
from langgraph.graph import MessagesState
from typing import Literal, Optional

class RouterGraphState(MessagesState):
    # Input question and schema
    question: str
    schema: str
    
    # Predicted difficulty level
    question_difficulty: Optional[str] = None
    
    # Extracted schema path for complex queries
    schema_path: Optional[str] = None
    
    # Final generated query
    query: Optional[str] = None

# %% [markdown]
# #### Node: Analyser (5 Points)

# %% [markdown]
# **Task:** Build a node that:
# * Accepts a question and schema
# * Analyzes the difficulty (simple/moderate/challanging)
# * Uses the LLM’s structured output feature to return the difficulty
#
# **Steps**:
#
# 1. Define a Pydantic class to hold the expected structured output.
# 2. Use structure output mode of LLM to bind it to the model.

# %%
from pydantic import BaseModel

class QuestionDifficultyAnalysis(BaseModel):
    difficulty: Literal["simple", "moderate", "challenging"]
    reasoning: str

def analyser_node(state: RouterGraphState):
    # Create structured output LLM for difficulty analysis
    structured_llm = llm.with_structured_output(QuestionDifficultyAnalysis)
    
    prompt = f"""Analyze the difficulty of this Text-to-SQL question based on the following criteria:

SIMPLE: 
- Single table queries
- Basic SELECT, WHERE, ORDER BY operations
- No joins or complex aggregations

MODERATE:
- 2-3 table joins
- Basic aggregations (COUNT, SUM, AVG)
- Simple subqueries

CHALLENGING:
- Complex multi-table joins (4+ tables)
- Complex aggregations or window functions
- Nested subqueries or CTEs
- Advanced SQL features

Question: {state["question"]}
Schema: {state["schema"]}

Provide your difficulty assessment and reasoning."""

    response = structured_llm.invoke(prompt)
    
    # Update state with difficulty analysis
    state["question_difficulty"] = response.difficulty
    
    return state

# %% [markdown]
# #### Conditional Edge (2 Points)

# %% [markdown]
# **Task:** Implement a branching function that decides whether to proceed to direct query generation or schema path extraction based on the difficulty label returned by the analyser.
#
# * If the difficulty is “easy”, go directly to query generation.
# * Otherwise, extract the schema path first.

# %%
def is_schema_extraction_needed(state: RouterGraphState) -> Literal["schema_path_extractor", "query_generator"]:
    # If the difficulty is simple, go directly to query generation
    if state["question_difficulty"] == "simple":
        return "query_generator"
    else:
        # For moderate and challenging questions, extract schema path first
        return "schema_path_extractor"

# %% [markdown]
# #### Node: Schema Extractor (3 Points)

# %% [markdown]
# **Task:** Implement a node that takes the question and schema and extracts a join path or sequence of relevant tables from the schema based on the question.
#
# * Use a simple prompt for this.
# * Store the result in the `schema_path` field of the state.

# %%
def schema_path_extractor_node(state: RouterGraphState):
    prompt = f"""Given a natural language question and database schema, identify the relevant tables and their relationships needed to answer the question. Extract a schema path that shows the join sequence between tables.

Question: {state["question"]}

Database Schema:
{state["schema"]}

Instructions:
- Identify which tables are needed to answer the question
- Determine the join relationships between these tables
- Provide a concise schema path showing how tables should be connected
- Focus on the most relevant columns for joins and filtering

Provide a clear schema path with table relationships and key columns."""

    response = llm.invoke(prompt)
    
    # Store the schema path in the state
    state["schema_path"] = response.content
    
    return state

# %% [markdown]
# #### Node: Generator (5 Points)

# %% [markdown]
# **Task:** Generate the SQL query based on the question and schema.
#
# * If a schema path is available, include it in the prompt.
# * Save the output query in the `query` field of the state.

# %%
def query_generator_node(state: RouterGraphState):
    # Build the prompt based on whether schema path is available
    base_prompt = f"""Generate a syntactically correct SQL query to answer the following question based on the provided database schema.

Question: {state["question"]}

Database Schema:
{state["schema"]}"""

    # Add schema path information if available
    if state["schema_path"]:
        enhanced_prompt = f"""{base_prompt}

Schema Path Analysis:
{state["schema_path"]}

Use the schema path analysis to guide your query construction, ensuring proper joins and table relationships."""
    else:
        enhanced_prompt = base_prompt

    enhanced_prompt += """

Instructions:
- Generate only the SQL query without explanation
- Ensure the query is syntactically correct
- Use proper SQL syntax and conventions
- Format your response as: ```sql\n[query]```"""

    response = llm.invoke(enhanced_prompt)
    
    # Store the generated query in the state
    state["query"] = response.content
    
    return state

# %% [markdown]
# #### Build Graph (5 Points)

# %% [markdown]
# **Task:** Assemble the full routing graph using the nodes and edges you created.

# %%
from langgraph.graph import StateGraph, START, END

router_graph_builder = StateGraph(RouterGraphState)

# Add nodes
router_graph_builder.add_node("analyser", analyser_node)
router_graph_builder.add_node("schema_path_extractor", schema_path_extractor_node)
router_graph_builder.add_node("query_generator", query_generator_node)

# Add edges
router_graph_builder.add_edge(START, "analyser")
router_graph_builder.add_conditional_edges(
    "analyser",
    is_schema_extraction_needed,
    ["schema_path_extractor", "query_generator"]
)
router_graph_builder.add_edge("schema_path_extractor", "query_generator")
router_graph_builder.add_edge("query_generator", END)

router_graph = router_graph_builder.compile()

# %% [markdown]
# #### Run and Evaluate (Estimated Run Time 10-15min)

# %% [markdown]
# **Task:** Run your compiled routing graph on a dataset. For each question:
#
# * Instantiate the `RouterGraphState` with the question and schema.
# * Run the graph to completion.
# * Extract and clean the query from the result.
#
# Use the `run_method` function to handle iteration and timing.

# %%
from method_run import run_method
def run_router_graph(item):
    response = router_graph.invoke(
        RouterGraphState(
            question=item['question'],
            schema=item['schema'],
            schema_path=None,
            question_difficulty=None,
            query=None
        )
    )
    result = response["query"]
    # First try to extract query from markdown SQL block
    match = re.search(r'```sql\n(.*?)```', result, re.DOTALL)
    if match:
        query = match.group(1).strip()
    else:
        # If no markdown block found, try to extract just SQL query
        query = result.strip()
        # Remove any ```sql or ``` if present without proper formatting
        query = re.sub(r'```sql|```', '', query).strip()
    print(f"Question: {item['question']}")
    print(f"Schema: {item['schema']}")
    print(f"Question Difficulty: {response['question_difficulty']}")
    if response["schema_path"]:
        print(f"Schema Path: {response['schema_path']}")
    print(f"Generated SQL: {query}\n")
    return {**item, 'sql': query}


run_method(run_router_graph, SLEEP_TIME=30)

#Run on mode=nano if you want to test it on a smaller dataset
#run_method(run_router_graph, SLEEP_TIME=10, mode="nano")
# Out:
# File not found: data/dev_databases/student_club/database_description/event.csv
# File not found: data/dev_databases/student_club/database_description/major.csv
# File not found: data/dev_databases/student_club/database_description/zip_code.csv
# File not found: data/dev_databases/student_club/database_description/attendance.csv
# File not found: data/dev_databases/student_club/database_description/budget.csv
# File not found: data/dev_databases/student_club/database_description/expense.csv
# File not found: data/dev_databases/student_club/database_description/income.csv
# File not found: data/dev_databases/student_club/database_description/member.csv
#   0%|          | 0/18 [00:00<?, ?it/s]
# Question: Find the percentage of atoms with single bond. (Evidence: single bond refers to bond_type = '-'; percentage = DIVIDE(SUM(bond_type = '-'), COUNT(bond_id)) as percentage)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables
# - `bond`: Contains information about bonds including the bond_type, which is needed to identify single bonds (where bond_type = '-')
#
# ## Observations
# - The question asks for the percentage of atoms with single bond
# - We need to calculate: COUNT(single bonds) / COUNT(total bonds)
# - The evidence indicates that single bonds are represented as bond_type = '-'
# - Only the `bond` table is needed as we're calculating a percentage based solely on bond types
#
# ## Schema Path
# `bond` → Filter where bond_type = '-' and calculate percentage
#
# This is a simple query that only requires the `bond` table to count bonds with bond_type = '-' compared to the total number of bonds.
#
# The calculation would be:
# ```
# SELECT (SUM(CASE WHEN bond_type = '-' THEN 1 ELSE 0 END) * 100.0 / COUNT(bond_id)) AS percentage
# FROM bond
# ```
# Generated SQL: SELECT (SUM(CASE WHEN bond_type = '-' THEN 1 ELSE 0 END) * 100.0 / COUNT(bond_id)) AS percentage
# FROM bond
#   6%|▌         | 1/18 [00:41<11:45, 41.50s/it]
# Question: Indicate which atoms are connected in non-carcinogenic type molecules. (Evidence: label = '-' means molecules are non-carcinogenic)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables
# - `molecule`: Contains the carcinogenic label information
# - `atom`: Contains atoms and their molecule associations
# - `connected`: Shows which atoms are connected to each other
# - `bond`: Contains bond information (though not essential for the core question)
#
# ## Schema Path
# ```
# molecule (molecule_id, label)
#     ↑
#     | molecule_id = molecule_id
#     ↓
# atom (atom_id, molecule_id, element)
#     ↑
#     | atom_id = atom_id/atom_id2
#     ↓
# connected (atom_id, atom_id2, bond_id)
# ```
#
# ## Explanation
# 1. Start with the `molecule` table to filter for non-carcinogenic molecules (where `label = '-'`)
# 2. Join with the `atom` table on `molecule_id` to get atoms in non-carcinogenic molecules
# 3. Join with the `connected` table on `atom_id` to identify which atoms are connected to each other
#
# This path will allow us to find all atom connections within non-carcinogenic molecules.
# Generated SQL: SELECT c.atom_id, c.atom_id2, a1.element AS element1, a2.element AS element2
# FROM molecule m
# JOIN atom a1 ON m.molecule_id = a1.molecule_id
# JOIN connected c ON a1.atom_id = c.atom_id
# JOIN atom a2 ON c.atom_id2 = a2.atom_id
# WHERE m.label = '-'
# ORDER BY c.atom_id, c.atom_id2
#  11%|█         | 2/18 [01:24<11:19, 42.44s/it]
# Question: What is the average number of bonds the atoms with the element iodine have? (Evidence: atoms with the element iodine refers to element = 'i'; average = DIVIDE(COUND(bond_id), COUNT(atom_id)) where element = 'i')
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Tables Needed
# - **atom**: Contains element information to filter for iodine atoms (element = 'i')
# - **connected**: Links atoms to bonds, needed to count bonds per atom
# - **bond**: Not directly needed for this query, but connected via the connected table
#
# ## Join Relationships
# - **atom** joins with **connected** on atom_id to find bonds associated with iodine atoms
#
# ## Schema Path
# ```
# atom [atom_id, element='i'] → connected [atom_id, bond_id]
# ```
#
# ## Reasoning
# To calculate the average number of bonds for iodine atoms, we need to:
# 1. Identify atoms where element = 'i' from the atom table
# 2. Join with the connected table to find all bonds associated with these atoms
# 3. Count the number of bond_id per atom_id
# 4. Calculate the average (total bonds / total iodine atoms)
#
# The most direct path involves joining atom and connected tables, focusing on atom_id and filtering by element = 'i'.
# Generated SQL: SELECT AVG(bond_count) AS avg_bonds_per_iodine_atom
# FROM (
#     SELECT a.atom_id, COUNT(DISTINCT c.bond_id) AS bond_count
#     FROM atom a
#     LEFT JOIN connected c ON a.atom_id = c.atom_id
#     WHERE a.element = 'i'
#     GROUP BY a.atom_id
# ) AS iodine_bonds
#  17%|█▋        | 3/18 [02:08<10:44, 42.96s/it]
# Question: List down two molecule id of triple bond non carcinogenic molecules with element carbon. (Evidence: carbon refers to element = 'c'; triple bond refers to bond_type = '#'; label = '-' means molecules are non-carcinogenic)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables and Columns
# - **molecule**: Contains molecule_id and label (where label = '-' for non-carcinogenic)
# - **atom**: Contains molecule_id and element (to filter for carbon elements where element = 'c')
# - **bond**: Contains molecule_id and bond_type (to filter for triple bonds where bond_type = '#')
#
# ## Schema Path
# ```
# molecule (molecule_id, label = '-')
#   |
#   +--> atom (molecule_id, element = 'c')
#   |
#   +--> bond (molecule_id, bond_type = '#')
# ```
#
# ## Join Relationships
# The query requires molecules that:
# 1. Are non-carcinogenic (molecule.label = '-')
# 2. Contain carbon atoms (atom.element = 'c')
# 3. Have triple bonds (bond.bond_type = '#')
#
# The tables can be joined using molecule_id as the common key, allowing us to find molecules that satisfy all three conditions.
#
# Note: While the "connected" table shows which atoms are connected by which bonds, we don't need this table to answer the specific question since we're only interested in the presence of triple bonds and carbon atoms within molecules, not their specific connections.
# Generated SQL: SELECT DISTINCT m.molecule_id
# FROM molecule m
# JOIN atom a ON m.molecule_id = a.molecule_id
# JOIN bond b ON m.molecule_id = b.molecule_id
# WHERE m.label = '-'
#   AND a.element = 'c'
#   AND b.bond_type = '#'
# LIMIT 2;
#  22%|██▏       | 4/18 [02:51<10:06, 43.30s/it]
# Question: What are the elements of the toxicology and label of molecule TR060? (Evidence: TR060 is the molecule id; label = '+' mean molecules are carcinogenic; label = '-' means molecules are non-carcinogenic; element = 'cl' means Chlorine; element = 'c' means Carbon; element = 'h' means Hydrogen; element = 'o' means Oxygen, element = 's' means Sulfur; element = 'n' means Nitrogen, element = 'p' means Phosphorus, element = 'na' means Sodium, element = 'br' means Bromine, element = 'f' means Fluorine; element = 'i' means Iodine; element = 'sn' means Tin; element = 'pb' means Lead; element = 'te' means Tellurium; element = 'ca' means Calcium)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Question Difficulty: simple
# Generated SQL: SELECT a.element, m.label
# FROM atom a
# JOIN molecule m ON a.molecule_id = m.molecule_id
# WHERE a.molecule_id = 'TR060'
#  28%|██▊       | 5/18 [03:29<08:55, 41.19s/it]
# Question: What are the elements for bond id TR001_10_11? (Evidence: element = 'cl' means Chlorine; element = 'c' means Carbon; element = 'h' means Hydrogen; element = 'o' means Oxygen, element = 's' means Sulfur; element = 'n' means Nitrogen, element = 'p' means Phosphorus, element = 'na' means Sodium, element = 'br' means Bromine, element = 'f' means Fluorine; element = 'i' means Iodine; element = 'sn' means Tin; element = 'pb' means Lead; element = 'te' means Tellurium; element = 'ca' means Calcium)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# Question Difficulty: moderate
# Schema Path: # Schema Analysis for the Question
#
# ## Tables Needed
# - `bond` - Contains the bond_id mentioned in the question (TR001_10_11)
# - `connected` - Links bonds to atoms
# - `atom` - Contains element information
#
# ## Relevant Columns
# - `bond.bond_id` - To filter for the specific bond ID "TR001_10_11"
# - `connected.bond_id` - To join with bond table
# - `connected.atom_id` and `connected.atom_id2` - To identify atoms connected by the bond
# - `atom.atom_id` - To join with connected table
# - `atom.element` - To get the element information
#
# ## Schema Path
# bond [bond_id = "TR001_10_11"] → connected [bond_id = bond.bond_id] → atom [atom_id = connected.atom_id OR atom_id = connected.atom_id2]
#
# This path allows us to find the specific bond by ID, identify which atoms are connected by this bond, and then retrieve the element information for those atoms.
# Generated SQL: SELECT DISTINCT a.element
# FROM bond b
# JOIN connected c ON b.bond_id = c.bond_id
# JOIN atom a ON (a.atom_id = c.atom_id OR a.atom_id = c.atom_id2)
# WHERE b.bond_id = 'TR001_10_11'
#  33%|███▎      | 6/18 [04:13<08:26, 42.18s/it]
# Question: How many superheroes were published by Dark Horse Comics? (Evidence: published by Dark Horse Comics refers to publisher_name = 'Dark Horse Comics';)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables
# - `superhero` - Contains the main superhero data
# - `publisher` - Contains publisher information including 'Dark Horse Comics'
#
# ## Key Relationships
# - `superhero.publisher_id` → `publisher.id` - Links superheroes to their publishers
#
# ## Schema Path
# ```
# superhero JOIN publisher ON superhero.publisher_id = publisher.id
# ```
#
# ## Filtering Condition
# - `publisher.publisher_name = 'Dark Horse Comics'`
#
# To answer the question about how many superheroes were published by Dark Horse Comics, we need to count superheroes from the `superhero` table where their publisher matches Dark Horse Comics in the `publisher` table.
# Generated SQL: SELECT COUNT(*)
# FROM superhero s
# JOIN publisher p ON s.publisher_id = p.id
# WHERE p.publisher_name = 'Dark Horse Comics'
#  39%|███▉      | 7/18 [04:53<07:35, 41.41s/it]
# Question: What are the race and alignment of Cameron Hicks? (Evidence: Cameron Hicks refers to superhero_name = 'Cameron Hicks';)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Tables Needed
# - `superhero`: Contains the superhero named Cameron Hicks and references to race and alignment
# - `race`: Contains race information
# - `alignment`: Contains alignment information
#
# ## Relevant Columns
# - `superhero.superhero_name`: To filter for "Cameron Hicks"
# - `superhero.race_id`: Foreign key to race table
# - `superhero.alignment_id`: Foreign key to alignment table
# - `race.id` and `race.race`: Primary key and race description
# - `alignment.id` and `alignment.alignment`: Primary key and alignment description
#
# ## Schema Path
# `superhero`
# → JOIN `race` ON `superhero.race_id` = `race.id`
# → JOIN `alignment` ON `superhero.alignment_id` = `alignment.id`
#
# ## Explanation
# To find the race and alignment of Cameron Hicks, we need to:
# 1. Find the superhero record where `superhero_name` = 'Cameron Hicks'
# 2. Use the `race_id` from that record to join with the `race` table
# 3. Use the `alignment_id` from that record to join with the `alignment` table
# 4. Retrieve the `race` and `alignment` values from their respective tables
# Generated SQL: SELECT r.race, a.alignment
# FROM superhero s
# JOIN race r ON s.race_id = r.id
# JOIN alignment a ON s.alignment_id = a.id
# WHERE s.superhero_name = 'Cameron Hicks'
#  44%|████▍     | 8/18 [05:35<06:57, 41.71s/it]
# Question: Among the superheroes with height from 170 to 190, list the names of the superheroes with no eye color. (Evidence: height from 170 to 190 refers to height_cm BETWEEN 170 AND 190; no eye color refers to eye_colour_id = 1)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Question Difficulty: simple
# Generated SQL: SELECT superhero_name
# FROM superhero
# WHERE height_cm BETWEEN 170 AND 190
# AND eye_colour_id = 1
#  50%|█████     | 9/18 [06:12<06:02, 40.25s/it]
# Question: List down at least five superpowers of male superheroes. (Evidence: male refers to gender = 'Male'; superpowers refers to power_name;)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables
# - `superhero`: Contains basic hero information including gender_id
# - `gender`: Contains gender values needed to filter for 'Male'
# - `hero_power`: Junction table linking heroes to their powers
# - `superpower`: Contains the power_name we need to display
#
# ## Schema Path
# ```
# superhero JOIN gender ON superhero.gender_id = gender.id
#     JOIN hero_power ON superhero.id = hero_power.hero_id
#         JOIN superpower ON hero_power.power_id = superpower.id
# ```
#
# ## Key Columns for Filtering and Selection
# - `gender.gender = 'Male'` - To filter for male superheroes
# - `superpower.power_name` - To display the superpowers
#
# This path allows us to:
# 1. Start with superheroes table
# 2. Filter for male superheroes by joining with gender table
# 3. Connect to their powers through the hero_power junction table
# 4. Retrieve the power names from the superpower table
# Generated SQL: SELECT DISTINCT sp.power_name
# FROM superhero sh
# JOIN gender g ON sh.gender_id = g.id
# JOIN hero_power hp ON sh.id = hp.hero_id
# JOIN superpower sp ON hp.power_id = sp.id
# WHERE g.gender = 'Male'
# LIMIT 5;
#  56%|█████▌    | 10/18 [06:55<05:28, 41.03s/it]
# Question: What is the percentage of superheroes who act in their own self-interest or make decisions based on their own moral code? Indicate how many of the said superheroes were published by Marvel Comics. (Evidence: published by Marvel Comics refers to publisher_name = 'Marvel Comics'; superheroes who act in their own self-interest or make decisions based on their own moral code refers to alignment = 'Bad'; calculation = MULTIPLY(DIVIDE(SUM(alignment = 'Bad); count(id)), 100))
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# Based on the question about superheroes who act in their own self-interest or make decisions based on their own moral code (defined as alignment = 'Bad') and those published by Marvel Comics, I'll identify the relevant tables and their relationships.
#
# ## Relevant Tables and Columns
# 1. `superhero` - Main table containing superhero records
# 2. `alignment` - Contains alignment information (Bad, Good, etc.)
# 3. `publisher` - Contains publisher information (Marvel Comics, etc.)
#
# ## Key Relationships
# - `superhero.alignment_id` joins with `alignment.id`
# - `superhero.publisher_id` joins with `publisher.id`
#
# ## Schema Path
# ```
# superhero
#   JOIN alignment ON superhero.alignment_id = alignment.id
#   JOIN publisher ON superhero.publisher_id = publisher.id
# ```
#
# ## Key Columns for Filtering and Calculation
# - `alignment.alignment` = 'Bad' (to identify superheroes who act in self-interest)
# - `publisher.publisher_name` = 'Marvel Comics' (to identify Marvel superheroes)
# - `superhero.id` (for counting total superheroes and those matching criteria)
#
# This schema path provides all necessary relationships to calculate the percentage of "Bad" superheroes and identify how many of them are published by Marvel Comics.
# Generated SQL: WITH bad_superheroes AS (
#     SELECT
#         s.id,
#         p.publisher_name
#     FROM
#         superhero s
#     JOIN
#         alignment a ON s.alignment_id = a.id
#     JOIN
#         publisher p ON s.publisher_id = p.id
#     WHERE
#         a.alignment = 'Bad'
# )
#
# SELECT
#     (COUNT(bs.id) * 100.0 / (SELECT COUNT(*) FROM superhero)) AS percentage_bad_alignment,
#     SUM(CASE WHEN bs.publisher_name = 'Marvel Comics' THEN 1 ELSE 0 END) AS marvel_bad_count
# FROM
#     bad_superheroes bs;
#  61%|██████    | 11/18 [07:40<04:55, 42.20s/it]
# Question: Which publisher created more superheroes: DC or Marvel Comics? Find the difference in the number of superheroes. (Evidence: DC refers to publisher_name = 'DC Comics'; Marvel Comics refers to publisher_name = 'Marvel Comics'; if SUM(publisher_name = 'DC Comics') > SUM(publisher_name = 'Marvel Comics'), it means DC Comics published more superheroes than Marvel Comics; if SUM(publisher_name = 'Marvel Comics') > SUM(publisher_name = 'Marvel Comics'), it means Marvel Comics published more heroes than DC Comics; difference = SUBTRACT(SUM(publisher_name = 'DC Comics'), SUM(publisher_name = 'Marvel Comics'));)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# Question Difficulty: moderate
# Schema Path: # Schema Analysis for Publisher Superhero Count Comparison
#
# ## Relevant Tables and Columns
# - `superhero`: Contains the main superhero records with publisher_id
# - `publisher`: Contains publisher names including 'DC Comics' and 'Marvel Comics'
#
# ## Join Relationships
# The question requires comparing the number of superheroes between DC Comics and Marvel Comics publishers. We need to:
# 1. Join the `superhero` table with the `publisher` table to get publisher names
# 2. Count superheroes grouped by publisher
# 3. Compare counts between DC Comics and Marvel Comics publishers
#
# ## Schema Path
# ```
# publisher (id, publisher_name)
#   ↑
#   | publisher_id = id
#   ↓
# superhero (id, superhero_name, publisher_id)
# ```
#
# This schema path allows us to count superheroes from each publisher by joining superhero records with their corresponding publisher names, then filtering for the specific publishers mentioned in the question (DC Comics and Marvel Comics) to calculate the difference in superhero counts.
# Generated SQL: WITH publisher_counts AS (
#   SELECT
#     p.publisher_name,
#     COUNT(s.id) AS superhero_count
#   FROM
#     publisher p
#   JOIN
#     superhero s ON p.id = s.publisher_id
#   WHERE
#     p.publisher_name IN ('DC Comics', 'Marvel Comics')
#   GROUP BY
#     p.publisher_name
# )
# SELECT
#   ABS(
#     (SELECT superhero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') -
#     (SELECT superhero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics')
#   ) AS superhero_count_difference,
#   CASE
#     WHEN (SELECT superhero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') >
#          (SELECT superhero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics')
#     THEN 'DC Comics'
#     ELSE 'Marvel Comics'
#   END AS publisher_with_more_superheroes
# FROM
#   dual;
#  67%|██████▋   | 12/18 [08:32<04:30, 45.10s/it]
# Question: Who was the first one paid his/her dues? Tell the full name. (Evidence: full name refers to first_name, last_name; first paid dues refers to MIN(received_date) where source = 'Dues')
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables
# - `member`: Contains personal information including first_name and last_name
# - `income`: Contains payment records including date_received and source fields
#
# ## Key Columns for Query
# - `member.first_name`, `member.last_name`: Needed for full name
# - `income.date_received`: Needed to determine who paid first
# - `income.source`: Needed to filter for "Dues" payments
# - `income.link_to_member`: Connects to member table
#
# ## Schema Path
# ```
# income [source='Dues'] → member
# (income.link_to_member = member.member_id)
# ```
#
# ## Query Logic
# 1. Filter income records where source = 'Dues'
# 2. Find the minimum date_received value from these records
# 3. Join to member table using link_to_member
# 4. Return the first_name and last_name from the member table
#
# This path enables identifying the member who first paid their dues by finding the earliest received_date in the income table (filtered for dues) and joining to the member table to retrieve their full name.
# Generated SQL: SELECT m.first_name, m.last_name
# FROM member m
# JOIN income i ON m.member_id = i.link_to_member
# WHERE i.source = 'Dues'
# AND i.date_received = (
#     SELECT MIN(date_received)
#     FROM income
#     WHERE source = 'Dues'
# )
#  72%|███████▏  | 13/18 [09:15<03:43, 44.67s/it]
# Question: How many income are received with an amount of 50? (Evidence: amount of 50 refers to amount = 50)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Question Difficulty: simple
# Generated SQL: SELECT COUNT(*)
# FROM income
# WHERE amount = 50
#  78%|███████▊  | 14/18 [09:50<02:47, 41.79s/it]
# Question: Name the event with the highest amount spent on advertisement. (Evidence: event refers to event_name; highest amount spent on advertisement refers to MAX(spent) where category = 'Advertisement')
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Tables Needed
# - `event`: Contains event_name which is required in the output
# - `budget`: Contains spent amount and category for filtering advertisements
#
# ## Relevant Columns
# - `event.event_id`, `event.event_name`: To identify the event
# - `budget.spent`: To find the highest amount spent
# - `budget.category`: To filter for 'Advertisement'
# - `budget.link_to_event`: To join with event table
#
# ## Schema Path
# ```
# event <-- budget
# (event.event_id = budget.link_to_event WHERE budget.category = 'Advertisement')
# ```
#
# ## Explanation
# To answer the question about which event had the highest amount spent on advertisement:
# 1. We need to join the `event` table with the `budget` table using `event.event_id = budget.link_to_event`
# 2. Filter the budget records where `category = 'Advertisement'`
# 3. Find the maximum value of `spent` among these records
# 4. Return the corresponding `event_name` from the event table
#
# This path allows us to connect spending information to the specific events, filter for advertisement expenses, and identify the event with the highest spending.
# Generated SQL: SELECT e.event_name
# FROM event e
# JOIN budget b ON e.event_id = b.link_to_event
# WHERE b.category = 'Advertisement'
# ORDER BY b.spent DESC
# LIMIT 1;
#  83%|████████▎ | 15/18 [10:35<02:07, 42.56s/it]
# Question: Based on the total cost for all event, what is the percentage of cost for Yearly Kickoff event? (Evidence: DIVIDE(SUM(cost where event_name = 'Yearly Kickoff'), SUM(cost)) * 100)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables
# The question asks for the percentage of cost for "Yearly Kickoff" event compared to the total cost for all events.
#
# Based on the evidence formula `DIVIDE(SUM(cost where event_name = 'Yearly Kickoff'), SUM(cost)) * 100`, I need:
# - Cost information for events
# - Event names to filter for "Yearly Kickoff"
#
# ## Required Tables
# 1. **event** - Contains event_name needed for filtering
# 2. **expense** - Contains cost information
# 3. **budget** - Links expenses to events
#
# ## Schema Path
# ```
# event (event_id)
#     ↑
#     | link_to_event
#     ↓
# budget (budget_id)
#     ↑
#     | link_to_budget
#     ↓
# expense (cost)
# ```
#
# ## Key Columns for Query
# - expense.cost - The cost values to sum
# - event.event_name - To filter for "Yearly Kickoff" event
# - budget.link_to_event - To join budget to event
# - expense.link_to_budget - To join expense to budget
#
# This path allows us to calculate the sum of costs for the specific event and compare it to the total sum of costs across all events.
# Generated SQL: WITH total_costs AS (
#   SELECT
#     e.event_name,
#     SUM(ex.cost) AS event_cost
#   FROM
#     event e
#     JOIN budget b ON e.event_id = b.link_to_event
#     JOIN expense ex ON b.budget_id = ex.link_to_budget
#   GROUP BY
#     e.event_name
# )
# SELECT
#   (SUM(CASE WHEN event_name = 'Yearly Kickoff' THEN event_cost ELSE 0 END) / SUM(event_cost)) * 100 AS yearly_kickoff_percentage
# FROM
#   total_costs;
#  89%|████████▉ | 16/18 [11:21<01:27, 43.66s/it]
# Question: Calculate the total average cost that Elijah Allen spent in the events on September and October. (Evidence: events in September and October refers to month(expense_date) = 9 AND MONTH(expense_date) = 10)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables and Columns
# - **expense**: Contains cost information and expense dates needed for calculating average cost
# - **member**: Contains information about members, including Elijah Allen
# - **budget**: Connects expenses to events
# - **event**: Contains event details
#
# ## Schema Path
# ```
# member (member_id, first_name, last_name)
#   ↑
#   | [join on member.member_id = expense.link_to_member]
#   ↓
# expense (expense_id, expense_date, cost, link_to_member, link_to_budget)
#   ↑
#   | [join on expense.link_to_budget = budget.budget_id]
#   ↓
# budget (budget_id, link_to_event)
#   ↑
#   | [join on budget.link_to_event = event.event_id]
#   ↓
# event (event_id)
# ```
#
# ## Query Logic
# 1. Filter member table for "Elijah Allen" (first_name = 'Elijah' AND last_name = 'Allen')
# 2. Find all expenses linked to this member
# 3. Filter expenses for September and October (MONTH(expense_date) = 9 OR MONTH(expense_date) = 10)
# 4. Calculate the average cost of these expenses
# 5. The path ensures we're only looking at expenses related to events through the budget table
# Generated SQL: SELECT AVG(e.cost) AS average_cost
# FROM expense e
# JOIN member m ON e.link_to_member = m.member_id
# WHERE m.first_name = 'Elijah'
#   AND m.last_name = 'Allen'
#   AND (MONTH(e.expense_date) = 9 OR MONTH(e.expense_date) = 10)
#   AND e.link_to_budget IN (SELECT budget_id FROM budget WHERE link_to_event IS NOT NULL)
#  94%|█████████▍| 17/18 [12:05<00:43, 43.74s/it]
# Question: Find the name and date of events with expenses for pizza that were more than fifty dollars but less than a hundred dollars. (Evidence: name of event refers to event_name; date of event refers to event_date; expenses for pizza refers to expense_description = 'Pizza' where cost > 50 and cost < 100)
# Schema: event (event_id, event_name, event_date, type, notes, location, status)
# major (major_id, major_name, department, college)
# zip_code (zip_code, type, city, county, state, short_state)
# attendance (link_to_event, link_to_member)
# budget (budget_id, category, spent, remaining, amount, event_status, link_to_event)
# expense (expense_id, expense_description, expense_date, cost, approved, link_to_member, link_to_budget)
# income (income_id, date_received, amount, source, notes, link_to_member)
# member (member_id, first_name, last_name, email, position, t_shirt_size, phone, zip, link_to_major)
#
# Question Difficulty: moderate
# Schema Path: # Schema Path Analysis
#
# ## Relevant Tables and Columns
# - **event**: Contains event_name and event_date (needed in the final output)
# - **expense**: Contains expense_description and cost (needed for filtering "Pizza" expenses between $50 and $100)
# - **budget**: Acts as the intermediary table that connects events to expenses
#
# ## Join Relationships
# The event table needs to be connected to the expense table, which can be done through the budget table:
# - budget.link_to_event connects to event.event_id
# - expense.link_to_budget connects to budget.budget_id
#
# ## Schema Path
# ```
# event ← budget → expense
# (event_id)  (link_to_event)  (link_to_budget)  (budget_id)
# ```
#
# ## Filtering Conditions
# - expense.expense_description = 'Pizza'
# - expense.cost > 50
# - expense.cost < 100
#
# ## Selection Columns
# - event.event_name
# - event.event_date
#
# This path allows us to find events with pizza expenses in the specified cost range by joining the event table through budget to the expense table, then applying the appropriate filters.
# Generated SQL: SELECT e.event_name, e.event_date
# FROM event e
# JOIN budget b ON e.event_id = b.link_to_event
# JOIN expense ex ON b.budget_id = ex.link_to_budget
# WHERE ex.expense_description = 'Pizza'
#   AND ex.cost > 50
#   AND ex.cost < 100
# 100%|██████████| 18/18 [12:48<00:00, 42.68s/it]
# Starting to compare without knowledge for ex
# Process finished successfully
# start calculate
#                      simple               moderate             challenging          total
# count                6                    6                    6                    18
# ======================================    ACCURACY    =====================================
# accuracy             66.67                100.00               83.33                83.33
# ===========================================================================================
# Finished evaluation

# %% [markdown]
# ### Agent (ReAct)

# %% [markdown]
# Now you will implement a full ReAct agent that incrementally solves the Text-to-SQL task using tools. The agent can explore tables and columns before finalizing the query.

# %% [markdown]
# **You are not allowed to use 'Prebuilt Agent' of LangGraph. You have to build your own graph.**

# %% [markdown]
# #### Define Tools

# %% [markdown]
# **Task:** Define three tools for the agent to interact with the schema:
# 1. `get_samples_from_table`: Returns the first few rows of a table.
# 2. `get_column_description`: Provides a human-readable description of a specific column.
# 3. `execute`: Executes a SQL query.

# %%
from langchain_core.tools import tool
from langchain_core.runnables import RunnableConfig
from langgraph.prebuilt import ToolNode

from db_manager import DBManager
db_manager = DBManager()

@tool
def get_samples_from_table(table_name: str, config: RunnableConfig):
  """Gets the first few rows (samples) from a specified table.

  Args:
    table_name: The name of the table from which to fetch samples.

  Returns:
    The first few rows from the specified table.
  """
  db_name = config["configurable"].get("database_name")
  result = db_manager.get_table_head(table_name, db_name=db_name)
  return result

@tool
def get_column_description(table_name: str, column_name: str, config: RunnableConfig):
  """Provides a description for a specific column within a given table.

  Args:
    table_name: The name of the table containing the column.
    column_name: The name of the column for which to get the description.

  Returns:
    A string containing the description of the specified column.
  """
  db_name = config["configurable"].get("database_name")
  result = db_manager.get_column_description(db_name, table_name, column_name)
  return result

@tool
def execute(query: str, config: RunnableConfig):
  """Executes a given SQL query against the database.

  Args:
    query: The SQL query string to be executed.

  Returns:
    The result of the executed query. This could be a set of rows,
    a confirmation message, or an error.
  """
  db_name = config["configurable"].get("database_name")
  result = db_manager.query(query, db_name)
  return result
# Out:
# File not found: data/dev_databases/student_club/database_description/event.csv
# File not found: data/dev_databases/student_club/database_description/major.csv
# File not found: data/dev_databases/student_club/database_description/zip_code.csv
# File not found: data/dev_databases/student_club/database_description/attendance.csv
# File not found: data/dev_databases/student_club/database_description/budget.csv
# File not found: data/dev_databases/student_club/database_description/expense.csv
# File not found: data/dev_databases/student_club/database_description/income.csv
# File not found: data/dev_databases/student_club/database_description/member.csv

# %% [markdown]
# #### Extra Tool (5+5 Bonus Points):

# %% [markdown]
# **Task**: Create and integrate a new custom tool into the ReAct agent. To receive credit for this part, your tool must be meaningfully different from the existing three tools and provide practical value in helping the agent generate more accurate or efficient SQL queries.

# %%
#YOUR CODE HERE

# %% [markdown]
# #### Create Tool Node

# %%
tools = [get_samples_from_table, get_column_description, execute]
tools_node = ToolNode(tools=tools)

# %% [markdown]
# #### ReAct Agent Prompt (5 Points)

# %% [markdown]
# **Task:** Set up the agent node with planning, tool use, and final SQL generation prompts. For writing efficient prompt you can read this link.
# https://cookbook.openai.com/examples/gpt4-1_prompting_guide

# %%
REACT_SYS_PROMPT = """
You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.

## Your Process:
1. **Understand the Question**: Carefully analyze what information is being requested
2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
4. **Generate SQL**: Create a syntactically correct and efficient SQL query
5. **Validate**: If possible, test your query to ensure it works correctly

## Available Tools:
- `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
- `get_column_description(table_name, column_name)`: Get detailed description of a specific column
- `execute(query)`: Execute a SQL query to test it or get results

## Guidelines:
- Always explore the schema first before writing queries
- Use sample data to understand data types and formats
- Consider relationships between tables when planning joins
- Generate clean, readable SQL with proper formatting
- Test your queries when possible to ensure correctness
- Provide only the final SQL query in ```sql``` format

## Response Format:
When you have your final query, format it as:
```sql
[your query here]
```

Begin by exploring the database schema to understand the structure before generating your query.
"""

# %% [markdown]
# #### Agent Node (5 Points)

# %% [markdown]
# **Task:** Set up the agent node with models that have binded with tools.

# %%
import time
from langchain_core.messages import SystemMessage, HumanMessage

def agent_node(state: MessagesState) -> MessagesState:
    time.sleep(10)

    # Bind tools
    agent_llm = llm.bind_tools(tools)

    # Always start with exactly one system message + all prior messages
    # (and drop any stray system messages in the middle)
    user_and_tool_messages = [
        m for m in state["messages"]
        if not isinstance(m, SystemMessage)
    ]
    messages = [SystemMessage(content=REACT_SYS_PROMPT)] + user_and_tool_messages

    # Invoke the LLM with tools
    response = agent_llm.invoke(messages)

    return {"messages": messages + [response]}

# %% [markdown]
# #### Build Graph (5 Points)

# %% [markdown]
# **Task:** Assemble the ReAct agent graph, connecting the agent node and tool node.

# %%
from langgraph.prebuilt import tools_condition
from typing_extensions import TypedDict

class ConfigSchema(TypedDict):
    database_name: str

react_builder = StateGraph(MessagesState, config_schema=ConfigSchema)

# Add nodes
react_builder.add_node("agent", agent_node)
react_builder.add_node("tools", tools_node)

# Add edges
react_builder.add_edge(START, "agent")
react_builder.add_conditional_edges(
    "agent",
    tools_condition,
    ["tools", END]
)
react_builder.add_edge("tools", "agent")

react_graph = react_builder.compile()

# %% [markdown]
# #### Run and Evaluate (Estimated Run Time 20min)

# %% [markdown]
# **Task:** Execute the ReAct agent pipeline on the dataset and collect SQL outputs.

# %%
from method_run import run_method
import re
def run_react_agent_with_config(item):
    question = item['question']
    schema = item['schema']
    user_prompt = f"Question: {question}\nSchema: {schema}"
    input_msg = HumanMessage(content=user_prompt)
    input_config = {"configurable": {"database_name": item['db_id']}}
    response = react_graph.invoke(MessagesState(messages=[input_msg]), config=input_config)

    for msg in response["messages"]:
        msg.pretty_print()
        
    # If last AI Message is a list of messages, we need to extract the last one
    last_msg = response["messages"][-1].content
    if isinstance(last_msg, list):
        last_msg = last_msg[-1]

    # First try to extract query from markdown SQL block
    match = re.search(r'```sql\n(.*?)```', last_msg, re.DOTALL)
    if match:
        query = match.group(1).strip()
    else:
        # If no markdown block found, try to extract just SQL query
        query = last_msg.strip()
        # Remove any ```sql or ``` if present without proper formatting
        query = re.sub(r'```sql|```', '', query).strip()

    return {**item, 'sql': query}

#Run agent on mode=nano, it's not needed to run on full dataset
run_method(run_react_agent_with_config, SLEEP_TIME=20, mode="nano")
# Out:
# File not found: data/dev_databases/student_club/database_description/event.csv
# File not found: data/dev_databases/student_club/database_description/major.csv
# File not found: data/dev_databases/student_club/database_description/zip_code.csv
# File not found: data/dev_databases/student_club/database_description/attendance.csv
# File not found: data/dev_databases/student_club/database_description/budget.csv
# File not found: data/dev_databases/student_club/database_description/expense.csv
# File not found: data/dev_databases/student_club/database_description/income.csv
# File not found: data/dev_databases/student_club/database_description/member.csv
#   0%|          | 0/5 [00:00<?, ?it/s]
# ================================ Human Message =================================
#
# Question: Find the percentage of atoms with single bond. (Evidence: single bond refers to bond_type = '-'; percentage = DIVIDE(SUM(bond_type = '-'), COUNT(bond_id)) as percentage)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "I'll help you find the percentage of atoms with single bonds. Let's start by exploring the schema to understand the data structure.", 'type': 'text'}, {'id': 'toolu_01HsGJDSgtUF9kF8CYQ2AkHU', 'input': {'table_name': 'atom'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_01HsGJDSgtUF9kF8CYQ2AkHU)
#  Call ID: toolu_01HsGJDSgtUF9kF8CYQ2AkHU
#   Args:
#     table_name: atom
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "atom"
# Columns Name: (atom_id, molecule_id, element)
# Row Values: (TR000_1, TR000, cl)
# Row Values: (TR000_2, TR000, c)
# Row Values: (TR000_3, TR000, cl)
# Row Values: (TR000_4, TR000, cl)
# Row Values: (TR000_5, TR000, h)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_01XndYysjevYARwk2KtNiZHT', 'input': {'table_name': 'bond'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_01XndYysjevYARwk2KtNiZHT)
#  Call ID: toolu_01XndYysjevYARwk2KtNiZHT
#   Args:
#     table_name: bond
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "bond"
# Columns Name: (bond_id, molecule_id, bond_type)
# Row Values: (TR000_1_2, TR000, -)
# Row Values: (TR000_2_3, TR000, -)
# Row Values: (TR000_2_4, TR000, -)
# Row Values: (TR000_2_5, TR000, -)
# Row Values: (TR001_10_11, TR001, =)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_019jGSuiPDVL6BE8AHroNP1Y', 'input': {'table_name': 'connected'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_019jGSuiPDVL6BE8AHroNP1Y)
#  Call ID: toolu_019jGSuiPDVL6BE8AHroNP1Y
#   Args:
#     table_name: connected
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "connected"
# Columns Name: (atom_id, atom_id2, bond_id)
# Row Values: (TR000_1, TR000_2, TR000_1_2)
# Row Values: (TR000_2, TR000_1, TR000_1_2)
# Row Values: (TR000_2, TR000_3, TR000_2_3)
# Row Values: (TR000_3, TR000_2, TR000_2_3)
# Row Values: (TR000_2, TR000_4, TR000_2_4)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "Now I understand the structure of the database. I need to:\n1. Count the total number of atoms that have bonds (are connected to other atoms)\n2. Count the number of atoms that have single bonds (bond_type = '-')\n3. Calculate the percentage\n\nLet's create an SQL query for this:\n\n```sql\nSELECT \n    ROUND(\n        (SUM(CASE WHEN b.bond_type = '-' THEN 1 ELSE 0 END) * 100.0) / \n        COUNT(DISTINCT c.atom_id),\n        2\n    ) AS percentage_single_bonds\nFROM \n    connected c\nJOIN \n    bond b ON c.bond_id = b.bond_id\n```\n\nLet me test this query to make sure it works:", 'type': 'text'}, {'id': 'toolu_01KAZekhnEu148jA6iyjwhmq', 'input': {'query': "SELECT \n    ROUND(\n        (SUM(CASE WHEN b.bond_type = '-' THEN 1 ELSE 0 END) * 100.0) / \n        COUNT(DISTINCT c.atom_id),\n        2\n    ) AS percentage_single_bonds\nFROM \n    connected c\nJOIN \n    bond b ON c.bond_id = b.bond_id"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_01KAZekhnEu148jA6iyjwhmq)
#  Call ID: toolu_01KAZekhnEu148jA6iyjwhmq
#   Args:
#     query: SELECT
#     ROUND(
#         (SUM(CASE WHEN b.bond_type = '-' THEN 1 ELSE 0 END) * 100.0) /
#         COUNT(DISTINCT c.atom_id),
#         2
#     ) AS percentage_single_bonds
# FROM
#     connected c
# JOIN
#     bond b ON c.bond_id = b.bond_id
# ================================= Tool Message =================================
# Name: execute
#
# [{"percentage_single_bonds": 170.68}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "The result seems unusual (over 100%). Let me reconsider the approach. I need to ensure I'm calculating the percentage correctly. I think the issue is that the connected table has duplicates since it represents both sides of a bond. Let me refine the query:\n\n```sql\nSELECT \n    ROUND(\n        (COUNT(DISTINCT CASE WHEN b.bond_type = '-' THEN c.atom_id END) * 100.0) / \n        COUNT(DISTINCT c.atom_id),\n        2\n    ) AS percentage_single_bonds\nFROM \n    connected c\nJOIN \n    bond b ON c.bond_id = b.bond_id\n```\n\nLet me test this modified query:", 'type': 'text'}, {'id': 'toolu_012jXB9oPNxofAJLbWZks7XT', 'input': {'query': "SELECT \n    ROUND(\n        (COUNT(DISTINCT CASE WHEN b.bond_type = '-' THEN c.atom_id END) * 100.0) / \n        COUNT(DISTINCT c.atom_id),\n        2\n    ) AS percentage_single_bonds\nFROM \n    connected c\nJOIN \n    bond b ON c.bond_id = b.bond_id"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_012jXB9oPNxofAJLbWZks7XT)
#  Call ID: toolu_012jXB9oPNxofAJLbWZks7XT
#   Args:
#     query: SELECT
#     ROUND(
#         (COUNT(DISTINCT CASE WHEN b.bond_type = '-' THEN c.atom_id END) * 100.0) /
#         COUNT(DISTINCT c.atom_id),
#         2
#     ) AS percentage_single_bonds
# FROM
#     connected c
# JOIN
#     bond b ON c.bond_id = b.bond_id
# ================================= Tool Message =================================
# Name: execute
#
# [{"percentage_single_bonds": 96.38}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "This looks more reasonable, but let me check one more thing. I need to ensure I'm not counting atoms multiple times if they have multiple bonds. Let's look at the data differently:", 'type': 'text'}, {'id': 'toolu_01KfvrRqNaYBoJqac15zcTEh', 'input': {'query': "WITH atom_bond_types AS (\n    SELECT DISTINCT\n        c.atom_id,\n        b.bond_type\n    FROM \n        connected c\n    JOIN \n        bond b ON c.bond_id = b.bond_id\n)\nSELECT \n    COUNT(DISTINCT atom_id) AS total_atoms,\n    COUNT(DISTINCT CASE WHEN bond_type = '-' THEN atom_id END) AS atoms_with_single_bonds,\n    ROUND(\n        (COUNT(DISTINCT CASE WHEN bond_type = '-' THEN atom_id END) * 100.0) / \n        COUNT(DISTINCT atom_id),\n        2\n    ) AS percentage_single_bonds\nFROM \n    atom_bond_types"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_01KfvrRqNaYBoJqac15zcTEh)
#  Call ID: toolu_01KfvrRqNaYBoJqac15zcTEh
#   Args:
#     query: WITH atom_bond_types AS (
#     SELECT DISTINCT
#         c.atom_id,
#         b.bond_type
#     FROM
#         connected c
#     JOIN
#         bond b ON c.bond_id = b.bond_id
# )
# SELECT
#     COUNT(DISTINCT atom_id) AS total_atoms,
#     COUNT(DISTINCT CASE WHEN bond_type = '-' THEN atom_id END) AS atoms_with_single_bonds,
#     ROUND(
#         (COUNT(DISTINCT CASE WHEN bond_type = '-' THEN atom_id END) * 100.0) /
#         COUNT(DISTINCT atom_id),
#         2
#     ) AS percentage_single_bonds
# FROM
#     atom_bond_types
# ================================= Tool Message =================================
# Name: execute
#
# [{"total_atoms": 9073, "atoms_with_single_bonds": 8745, "percentage_single_bonds": 96.38}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# Based on the evidence in the question and my analysis, here's the final SQL query to find the percentage of atoms with single bonds:
#
# ```sql
# WITH atom_bond_types AS (
#     SELECT DISTINCT
#         c.atom_id,
#         b.bond_type
#     FROM
#         connected c
#     JOIN
#         bond b ON c.bond_id = b.bond_id
# )
# SELECT
#     ROUND(
#         (COUNT(DISTINCT CASE WHEN bond_type = '-' THEN atom_id END) * 100.0) /
#         COUNT(DISTINCT atom_id),
#         2
#     ) AS percentage
# FROM
#     atom_bond_types
# ```
#  20%|██        | 1/5 [02:05<08:20, 125.22s/it]
# ================================ Human Message =================================
#
# Question: What are the elements for bond id TR001_10_11? (Evidence: element = 'cl' means Chlorine; element = 'c' means Carbon; element = 'h' means Hydrogen; element = 'o' means Oxygen, element = 's' means Sulfur; element = 'n' means Nitrogen, element = 'p' means Phosphorus, element = 'na' means Sodium, element = 'br' means Bromine, element = 'f' means Fluorine; element = 'i' means Iodine; element = 'sn' means Tin; element = 'pb' means Lead; element = 'te' means Tellurium; element = 'ca' means Calcium)
# Schema: atom (atom_id, molecule_id, element)
# bond (bond_id, molecule_id, bond_type)
# connected (atom_id, atom_id2, bond_id)
# molecule (molecule_id, label)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "I'll help you find the elements for bond id TR001_10_11 by first exploring the database schema and then querying the relevant information.\n\nLet's start by examining the tables structure and sample data to understand how the data is organized.", 'type': 'text'}, {'id': 'toolu_01HHUfbqdRhMQr67MmUrAXMW', 'input': {'table_name': 'atom'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_01HHUfbqdRhMQr67MmUrAXMW)
#  Call ID: toolu_01HHUfbqdRhMQr67MmUrAXMW
#   Args:
#     table_name: atom
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "atom"
# Columns Name: (atom_id, molecule_id, element)
# Row Values: (TR000_1, TR000, cl)
# Row Values: (TR000_2, TR000, c)
# Row Values: (TR000_3, TR000, cl)
# Row Values: (TR000_4, TR000, cl)
# Row Values: (TR000_5, TR000, h)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_016CM9h1Wct3pfv49qA4m3Sp', 'input': {'table_name': 'bond'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_016CM9h1Wct3pfv49qA4m3Sp)
#  Call ID: toolu_016CM9h1Wct3pfv49qA4m3Sp
#   Args:
#     table_name: bond
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "bond"
# Columns Name: (bond_id, molecule_id, bond_type)
# Row Values: (TR000_1_2, TR000, -)
# Row Values: (TR000_2_3, TR000, -)
# Row Values: (TR000_2_4, TR000, -)
# Row Values: (TR000_2_5, TR000, -)
# Row Values: (TR001_10_11, TR001, =)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_01KSSoyS1FuDyadQYSJPVpsx', 'input': {'table_name': 'connected'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_01KSSoyS1FuDyadQYSJPVpsx)
#  Call ID: toolu_01KSSoyS1FuDyadQYSJPVpsx
#   Args:
#     table_name: connected
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "connected"
# Columns Name: (atom_id, atom_id2, bond_id)
# Row Values: (TR000_1, TR000_2, TR000_1_2)
# Row Values: (TR000_2, TR000_1, TR000_1_2)
# Row Values: (TR000_2, TR000_3, TR000_2_3)
# Row Values: (TR000_3, TR000_2, TR000_2_3)
# Row Values: (TR000_2, TR000_4, TR000_2_4)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': 'Now I understand the schema structure. To find the elements for bond id TR001_10_11, I need to:\n1. Find the atoms connected by this bond from the "connected" table\n2. Look up the elements of those atoms in the "atom" table\n\nLet\'s execute the query:', 'type': 'text'}, {'id': 'toolu_01Xcspr3fcpexE4VvYmJNPS7', 'input': {'query': "SELECT c.bond_id, c.atom_id, c.atom_id2, a1.element as element1, a2.element as element2\nFROM connected c\nJOIN atom a1 ON c.atom_id = a1.atom_id\nJOIN atom a2 ON c.atom_id2 = a2.atom_id\nWHERE c.bond_id = 'TR001_10_11'"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_01Xcspr3fcpexE4VvYmJNPS7)
#  Call ID: toolu_01Xcspr3fcpexE4VvYmJNPS7
#   Args:
#     query: SELECT c.bond_id, c.atom_id, c.atom_id2, a1.element as element1, a2.element as element2
# FROM connected c
# JOIN atom a1 ON c.atom_id = a1.atom_id
# JOIN atom a2 ON c.atom_id2 = a2.atom_id
# WHERE c.bond_id = 'TR001_10_11'
# ================================= Tool Message =================================
# Name: execute
#
# [{"bond_id": "TR001_10_11", "atom_id": "TR001_10", "atom_id2": "TR001_11", "element1": "c", "element2": "o"}, {"bond_id": "TR001_10_11", "atom_id": "TR001_11", "atom_id2": "TR001_10", "element1": "o", "element2": "c"}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# Based on the query results, I can see that bond TR001_10_11 connects two atoms:
# 1. Atom TR001_10 which is a Carbon (c) element
# 2. Atom TR001_11 which is an Oxygen (o) element
#
# Therefore, the elements for bond id TR001_10_11 are Carbon and Oxygen.
#
# Here's the final SQL query that answers the question:
#
# ```sql
# SELECT c.bond_id, c.atom_id, c.atom_id2, a1.element as element1, a2.element as element2
# FROM connected c
# JOIN atom a1 ON c.atom_id = a1.atom_id
# JOIN atom a2 ON c.atom_id2 = a2.atom_id
# WHERE c.bond_id = 'TR001_10_11'
# ```
#  40%|████      | 2/5 [03:36<05:16, 105.40s/it]
# ================================ Human Message =================================
#
# Question: Which publisher created more superheroes: DC or Marvel Comics? Find the difference in the number of superheroes. (Evidence: DC refers to publisher_name = 'DC Comics'; Marvel Comics refers to publisher_name = 'Marvel Comics'; if SUM(publisher_name = 'DC Comics') > SUM(publisher_name = 'Marvel Comics'), it means DC Comics published more superheroes than Marvel Comics; if SUM(publisher_name = 'Marvel Comics') > SUM(publisher_name = 'Marvel Comics'), it means Marvel Comics published more heroes than DC Comics; difference = SUBTRACT(SUM(publisher_name = 'DC Comics'), SUM(publisher_name = 'Marvel Comics'));)
# Schema: alignment (id, alignment)
# attribute (id, attribute_name)
# colour (id, colour)
# gender (id, gender)
# publisher (id, publisher_name)
# race (id, race)
# superhero (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# hero_attribute (hero_id, attribute_id, attribute_value)
# superpower (id, power_name)
# hero_power (hero_id, power_id)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "I'll help you answer this question by exploring the database schema and creating a SQL query to compare the number of superheroes between DC Comics and Marvel Comics.\n\nFirst, let's examine the superhero table to understand its structure:", 'type': 'text'}, {'id': 'toolu_013cyBwHGWaNVKnKASkndKUe', 'input': {'table_name': 'superhero'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_013cyBwHGWaNVKnKASkndKUe)
#  Call ID: toolu_013cyBwHGWaNVKnKASkndKUe
#   Args:
#     table_name: superhero
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "superhero"
# Columns Name: (id, superhero_name, full_name, gender_id, eye_colour_id, hair_colour_id, skin_colour_id, race_id, publisher_id, alignment_id, height_cm, weight_kg)
# Row Values: (1, 3-D Man, Charles Chandler, 1, 9, 13, 1, 1, 13, 1, 188, 90)
# Row Values: (2, A-Bomb, Richard Milhouse Jones, 1, 33, 1, 1, 24, 13, 1, 203, 441)
# Row Values: (3, Abe Sapien, Abraham Sapien, 1, 7, 1, 7, 33, 3, 1, 191, 65)
# Row Values: (4, Abin Sur, -, 1, 7, 1, 23, 55, 4, 1, 185, 90)
# Row Values: (5, Abomination, Emil Blonsky, 1, 14, 1, 1, 28, 13, 2, 203, 441)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "Now, let's also look at the publisher table to understand how publishers are stored:", 'type': 'text'}, {'id': 'toolu_01Tn8ZDcmZfo4xeJWtHaRP2P', 'input': {'table_name': 'publisher'}, 'name': 'get_samples_from_table', 'type': 'tool_use'}]
# Tool Calls:
#   get_samples_from_table (toolu_01Tn8ZDcmZfo4xeJWtHaRP2P)
#  Call ID: toolu_01Tn8ZDcmZfo4xeJWtHaRP2P
#   Args:
#     table_name: publisher
# ================================= Tool Message =================================
# Name: get_samples_from_table
#
# Table Name: "publisher"
# Columns Name: (id, publisher_name)
# Row Values: (1, )
# Row Values: (2, ABC Studios)
# Row Values: (3, Dark Horse Comics)
# Row Values: (4, DC Comics)
# Row Values: (5, George Lucas)
#
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': 'I need to confirm the publisher_id values that correspond to DC Comics and Marvel Comics:', 'type': 'text'}, {'id': 'toolu_01GWg5BMm5xpgcrR1aiwtNLR', 'input': {'query': "SELECT id, publisher_name FROM publisher WHERE publisher_name IN ('DC Comics', 'Marvel Comics')"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_01GWg5BMm5xpgcrR1aiwtNLR)
#  Call ID: toolu_01GWg5BMm5xpgcrR1aiwtNLR
#   Args:
#     query: SELECT id, publisher_name FROM publisher WHERE publisher_name IN ('DC Comics', 'Marvel Comics')
# ================================= Tool Message =================================
# Name: execute
#
# [{"id": 4, "publisher_name": "DC Comics"}, {"id": 13, "publisher_name": "Marvel Comics"}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': 'Now I can create a query to count the number of superheroes from each publisher and calculate the difference:', 'type': 'text'}, {'id': 'toolu_0164ykC1QfGSYNn2zVHbZ35w', 'input': {'query': "WITH publisher_counts AS (\n    SELECT \n        p.publisher_name,\n        COUNT(s.id) AS hero_count\n    FROM \n        superhero s\n    JOIN \n        publisher p ON s.publisher_id = p.id\n    WHERE \n        p.publisher_name IN ('DC Comics', 'Marvel Comics')\n    GROUP BY \n        p.publisher_name\n)\nSELECT \n    (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') AS dc_count,\n    (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics') AS marvel_count,\n    ABS((SELECT hero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') - \n        (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics')) AS difference,\n    CASE \n        WHEN (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') > \n             (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics')\n        THEN 'DC Comics'\n        ELSE 'Marvel Comics'\n    END AS publisher_with_more_heroes"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_0164ykC1QfGSYNn2zVHbZ35w)
#  Call ID: toolu_0164ykC1QfGSYNn2zVHbZ35w
#   Args:
#     query: WITH publisher_counts AS (
#     SELECT
#         p.publisher_name,
#         COUNT(s.id) AS hero_count
#     FROM
#         superhero s
#     JOIN
#         publisher p ON s.publisher_id = p.id
#     WHERE
#         p.publisher_name IN ('DC Comics', 'Marvel Comics')
#     GROUP BY
#         p.publisher_name
# )
# SELECT
#     (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') AS dc_count,
#     (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics') AS marvel_count,
#     ABS((SELECT hero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') -
#         (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics')) AS difference,
#     CASE
#         WHEN (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'DC Comics') >
#              (SELECT hero_count FROM publisher_counts WHERE publisher_name = 'Marvel Comics')
#         THEN 'DC Comics'
#         ELSE 'Marvel Comics'
#     END AS publisher_with_more_heroes
# ================================= Tool Message =================================
# Name: execute
#
# [{"dc_count": 224, "marvel_count": 387, "difference": 163, "publisher_with_more_heroes": "Marvel Comics"}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# Based on the query results, here's the final SQL query to answer the question:
#
# ```sql
# WITH publisher_counts AS (
# ...
#
# ================================== Ai Message ==================================
#
# [{'text': 'Let me try to get more information about the expense and budget tables:', 'type': 'text'}, {'id': 'toolu_01EYkgZ85gzMBwDsJfq9cKYo', 'input': {'table_name': 'expense', 'column_name': 'cost'}, 'name': 'get_column_description', 'type': 'tool_use'}]
# Tool Calls:
#   get_column_description (toolu_01EYkgZ85gzMBwDsJfq9cKYo)
#  Call ID: toolu_01EYkgZ85gzMBwDsJfq9cKYo
#   Args:
#     table_name: expense
#     column_name: cost
# ================================= Tool Message =================================
# Name: get_column_description
#
# Error: ValueError('No schema found for column: cost in table: expense of database: student_club')
#  Please fix your mistakes.
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "Let's try running a simple query to better understand the relationship between these tables:", 'type': 'text'}, {'id': 'toolu_01TTGZnp3oEXrTC1ypZpQ7V3', 'input': {'query': "SELECT * FROM event WHERE event_name = 'Yearly Kickoff' LIMIT 1;"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_01TTGZnp3oEXrTC1ypZpQ7V3)
#  Call ID: toolu_01TTGZnp3oEXrTC1ypZpQ7V3
#   Args:
#     query: SELECT * FROM event WHERE event_name = 'Yearly Kickoff' LIMIT 1;
# ================================= Tool Message =================================
# Name: execute
#
# [{"event_id": "recykdvf4LgsyA3wZ", "event_name": "Yearly Kickoff", "event_date": "2019-09-03T12:00:00", "type": "Meeting", "notes": null, "location": "MU 215", "status": "Closed"}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "Great, I found the Yearly Kickoff event. Now let's explore the relationship between expense, budget, and events:", 'type': 'text'}, {'id': 'toolu_01TYjF4QeNBaAcXRYxubU9n9', 'input': {'query': "SELECT * FROM budget WHERE link_to_event = 'recykdvf4LgsyA3wZ' LIMIT 5;"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_01TYjF4QeNBaAcXRYxubU9n9)
#  Call ID: toolu_01TYjF4QeNBaAcXRYxubU9n9
#   Args:
#     query: SELECT * FROM budget WHERE link_to_event = 'recykdvf4LgsyA3wZ' LIMIT 5;
# ================================= Tool Message =================================
# Name: execute
#
# [{"budget_id": "recca5tkvdQgoLKZz", "category": "Food", "spent": 327.07, "remaining": 22.9299999999999, "amount": 350, "event_status": "Closed", "link_to_event": "recykdvf4LgsyA3wZ"}, {"budget_id": "recvKTAWAFKkVNnXQ", "category": "Advertisement", "spent": 122.06, "remaining": 27.94, "amount": 150, "event_status": "Closed", "link_to_event": "recykdvf4LgsyA3wZ"}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': "Now let's look at how expenses are linked to budgets:", 'type': 'text'}, {'id': 'toolu_01GE2F2feRciTE3JnNC4CmbR', 'input': {'query': "SELECT * FROM expense WHERE link_to_budget IN ('recca5tkvdQgoLKZz', 'recvKTAWAFKkVNnXQ') LIMIT 5;"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_01GE2F2feRciTE3JnNC4CmbR)
#  Call ID: toolu_01GE2F2feRciTE3JnNC4CmbR
#   Args:
#     query: SELECT * FROM expense WHERE link_to_budget IN ('recca5tkvdQgoLKZz', 'recvKTAWAFKkVNnXQ') LIMIT 5;
# ================================= Tool Message =================================
# Name: execute
#
# [{"expense_id": "rec017x6R3hQqkLAo", "expense_description": "Post Cards, Posters", "expense_date": "2019-08-20", "cost": 122.06, "approved": "true", "link_to_member": "rec4BLdZHS2Blfp4v", "link_to_budget": "recvKTAWAFKkVNnXQ"}, {"expense_id": "recNQk5EsFhOWLl4R", "expense_description": "Pizza", "expense_date": "2019-09-03", "cost": 103.62, "approved": "true", "link_to_member": "recro8T1MPMwRadVH", "link_to_budget": "recca5tkvdQgoLKZz"}, {"expense_id": "recgd6PuR9E84egT5", "expense_description": "Water, Veggie tray, supplies", "expense_date": "2019-09-03", "cost": 28.15, "approved": "true", "link_to_member": "recro8T1MPMwRadVH", "link_to_budget": "recca5tkvdQgoLKZz"}, {"expense_id": "recytertXPNtYtkC3", "expense_description": "Bakery - Donuts, muffins", "expense_date": "2019-09-03", "cost": 195.3, "approved": "true", "link_to_member": "rec4BLdZHS2Blfp4v", "link_to_budget": "recca5tkvdQgoLKZz"}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# [{'text': 'Now I understand the data structure. Let\'s write the SQL query to calculate the percentage of cost for the "Yearly Kickoff" event:', 'type': 'text'}, {'id': 'toolu_013AuTfJCS8irKoZjxPaxPux', 'input': {'query': "WITH \nyearly_kickoff_cost AS (\n    SELECT SUM(e.cost) AS total_yearly_kickoff_cost\n    FROM expense e\n    JOIN budget b ON e.link_to_budget = b.budget_id\n    JOIN event ev ON b.link_to_event = ev.event_id\n    WHERE ev.event_name = 'Yearly Kickoff'\n),\nall_events_cost AS (\n    SELECT SUM(e.cost) AS total_all_events_cost\n    FROM expense e\n    JOIN budget b ON e.link_to_budget = b.budget_id\n    JOIN event ev ON b.link_to_event = ev.event_id\n)\nSELECT \n    yearly_kickoff_cost.total_yearly_kickoff_cost AS yearly_kickoff_cost,\n    all_events_cost.total_all_events_cost AS all_events_cost,\n    (yearly_kickoff_cost.total_yearly_kickoff_cost / all_events_cost.total_all_events_cost) * 100 AS percentage\nFROM \n    yearly_kickoff_cost, all_events_cost;"}, 'name': 'execute', 'type': 'tool_use'}]
# Tool Calls:
#   execute (toolu_013AuTfJCS8irKoZjxPaxPux)
#  Call ID: toolu_013AuTfJCS8irKoZjxPaxPux
#   Args:
#     query: WITH
# yearly_kickoff_cost AS (
#     SELECT SUM(e.cost) AS total_yearly_kickoff_cost
#     FROM expense e
#     JOIN budget b ON e.link_to_budget = b.budget_id
#     JOIN event ev ON b.link_to_event = ev.event_id
#     WHERE ev.event_name = 'Yearly Kickoff'
# ),
# all_events_cost AS (
#     SELECT SUM(e.cost) AS total_all_events_cost
#     FROM expense e
#     JOIN budget b ON e.link_to_budget = b.budget_id
#     JOIN event ev ON b.link_to_event = ev.event_id
# )
# SELECT
#     yearly_kickoff_cost.total_yearly_kickoff_cost AS yearly_kickoff_cost,
#     all_events_cost.total_all_events_cost AS all_events_cost,
#     (yearly_kickoff_cost.total_yearly_kickoff_cost / all_events_cost.total_all_events_cost) * 100 AS percentage
# FROM
#     yearly_kickoff_cost, all_events_cost;
# ================================= Tool Message =================================
# Name: execute
#
# [{"yearly_kickoff_cost": 449.13, "all_events_cost": 2086.05, "percentage": 21.530164665276477}]
# ================================ System Message ================================
#
#
# You are an expert SQL query generation agent with access to database exploration tools. Your task is to generate accurate SQL queries by systematically analyzing the database schema and understanding the relationships between tables.
#
# ## Your Process:
# 1. **Understand the Question**: Carefully analyze what information is being requested
# 2. **Explore the Schema**: Use available tools to understand table structures, relationships, and sample data
# 3. **Plan Your Query**: Think through the necessary joins, filters, and aggregations
# 4. **Generate SQL**: Create a syntactically correct and efficient SQL query
# 5. **Validate**: If possible, test your query to ensure it works correctly
#
# ## Available Tools:
# - `get_samples_from_table(table_name)`: Get sample rows from a table to understand data structure
# - `get_column_description(table_name, column_name)`: Get detailed description of a specific column
# - `execute(query)`: Execute a SQL query to test it or get results
#
# ## Guidelines:
# - Always explore the schema first before writing queries
# - Use sample data to understand data types and formats
# - Consider relationships between tables when planning joins
# - Generate clean, readable SQL with proper formatting
# - Test your queries when possible to ensure correctness
# - Provide only the final SQL query in ```sql``` format
#
# ## Response Format:
# When you have your final query, format it as:
# ```sql
# [your query here]
# ```
#
# Begin by exploring the database schema to understand the structure before generating your query.
#
# ================================== Ai Message ==================================
#
# Based on the results, here's the final SQL query that calculates the percentage of cost for the Yearly Kickoff event compared to all events:
#
# ```sql
# WITH
# yearly_kickoff_cost AS (
#     SELECT SUM(e.cost) AS total_yearly_kickoff_cost
#     FROM expense e
#     JOIN budget b ON e.link_to_budget = b.budget_id
#     JOIN event ev ON b.link_to_event = ev.event_id
#     WHERE ev.event_name = 'Yearly Kickoff'
# ),
# all_events_cost AS (
#     SELECT SUM(e.cost) AS total_all_events_cost
#     FROM expense e
#     JOIN budget b ON e.link_to_budget = b.budget_id
#     JOIN event ev ON b.link_to_event = ev.event_id
# )
# SELECT
#     (yearly_kickoff_cost.total_yearly_kickoff_cost / all_events_cost.total_all_events_cost) * 100 AS percentage
# FROM
#     yearly_kickoff_cost, all_events_cost;
# ```
#
# This query shows that the Yearly Kickoff event accounts for approximately 21.53% of the total cost for all events.
# 100%|██████████| 5/5 [09:05<00:00, 109.12s/it]
# Starting to compare without knowledge for ex
# Process finished successfully
# start calculate
#                      simple               moderate             challenging          total
# count                1                    1                    3                    5
# ======================================    ACCURACY    =====================================
# accuracy             0.00                 0.00                 0.00                 0.00
# ===========================================================================================
# Finished evaluation
